# %% [markdown]
# <a href="https://colab.research.google.com/github/Dayana-cpu/Iniciando-Projeto-de-Dados-/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Dados Pessoais
#
#  - Nome: Dayana Dayse Cavalcante da Silva
#  - Email: dayana@dcampos.com.br
#  - Linkedin: Dayana Cavalcante
#  - Instagram: dayycavalcante

# %% [markdown]
# ## 2. Objetivo:
#   - Desenvolver ferramentas para analise de dados preditiva para meus clientes
#   - Import-- Tidy --Transform

# %% [markdown]
# # 3. Habilidades (Hard e Soft Skills)
#
#
# ## 3.1 **Hard Skills**
#   - Desenvolvedor de Ferramenta em planejamento
#   - Programação em Python, SQL, estatística e visualização de dados, que permitem transformar dados em insights concretos.
#
# ## 3.2 **Soft Skills**
# - competências comportamentais, como comunicação clara, pensamento crítico e colaboração, que garantem que esses insights sejam compreendidos e usados na tomada de decisão.

# %% [markdown]
# # 4. Breve Descrição sobre minhas Skills
#  - ausencia do uso continuo das Ferramentas

# %% [markdown]
# # 8. Estratégia
#  - analista ou cientista de dados
#  - Qual problema de negócio estamos tentando resolver?
#    Quais decisões serão tomadas com base nesses resultados?
#    Quem vai usar essa análise?
#    eu preciso verificra as respostas para essas perguntas, e definir o escopo do projeto, a metodologia a ser usada e como os resultados serão apresentados para serem realmente úteis
#   - Estratégia -- Plano -- Monitoramento/analise/ferramentas/dados -- Atuação/Ajuste = Ciclo BPM (Business Performance Management)
#   - Para Onde? ( estabelecer com meta ) -- Como Chegaremos? ( Plano Operacional ) / Atuação e Ajustes?

# %% [markdown]
# # 9. Estatística
#  - identificar padrões em receitas, despesas, tributos e indicadores contábeis, apoiando previsões e comparações entre períodos.
#   - fornecendo base sólida para gestores tomarem decisões estratégicas com menor risco e maior eficiência tributária

# %%
# Média

a = [2, 4, 6, 8, 10]
print(f'Média: {sum(a) / len(a)}')
# Out:
# Média: 6.0

# %%
import statistics as st
print(f'Média: {st.mean(a)}')
# Out:
# Média: 6

# %%
import numpy as np

import pandas as pd

from statistics import mode

notas = [8, 7, 6, 9, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]

media = np.mean(notas)

mediana = np.median(notas)

moda = mode(notas)

print("Média   :", media)

print("Mediana :", mediana)

print("Moda    :", moda)
# Out:
# Média   : 7.55
# Mediana : 8.0
# Moda    : 8

# %%
# número ímpar de elementos
b = [1500, 1800, 2000, 2100, 2200, 2400]
print(f'Mediana: {sorted(b)[len(b) // 2] if len(b) % 2 != 0 else (sorted(b)[len(b) // 2 - 1] + sorted(b)[len(b) // 2]) / 2}')
# Out:
# Mediana: 2050.0

# %%
amplitude = max(notas) - min(notas)
variancia = np.var(notas, ddof=1)   # ddof=1 → amostral
desvio_padrao = np.std(notas, ddof=1)
cv = desvio_padrao / media
print("Amplitude        :", amplitude)
print("Variância        :", variancia)
print("Desvio Padrão    :", desvio_padrao)
print("Coef. Variação   :", cv)
# Out:
# Amplitude        : 8
# Variância        : 3.8394736842105264
# Desvio Padrão    : 1.9594574974238472
# Coef. Variação   : 0.2595307943607745

# %%
2 + 2
# Out:
# 4

# %%
10 - 5
# Out:
# 5

# %%
10 / 5
# Out:
# 2.0

# %%
10 * 2
# Out:
# 20

# %%
nome = input('qual é o seu nome?')
print ( f'olá {nome}')
# Out:
# qual é o seu nome?Dayana
# olá Dayana

# %%
nome = input(' Qual é o seu nome')
print (f'olá {nome}, como posso ajudar ?')
# Out:
#  Qual é o seu nomeDayana
# olá Dayana, como posso ajudar ?

# %%
a = "Dayana"
print(type(a))
# Out:
# <class 'str'>

# %%
b = 10
print(type(b))
# Out:
# <class 'int'>

# %%
c = 10.5
print(type(c))
# Out:
# <class 'float'>

# %%
 d = True
 print(type(d))
# Out:
# <class 'bool'>

# %%
 a = 10
 b = 5
 soma = a + b
 print(soma)
# Out:
# 15

# %%
 a = "10"
 b = "5"
 soma = a + b
 print(soma)
# Out:
# 105

# %%
 nome = "Dayana"
 sobrenomme = "Dayse"
 nome_completo = nome + " " + sobrenomme
 print(nome_completo)
# Out:
# Dayana Dayse

# %%
 nome = "Dayana"
 sobrenome = "Cavalcante"
 print(nome + " " + sobrenome)
# Out:
# Dayana Cavalcante

# %%
nome = "Dayana"

sobrenome = "Cavalcante"

nome_completo = f'{nome} {sobrenome}'

print(nome_completo)
# Out:
# Dayana Cavalcante

# %%
nome = "Dayana"

sobrenome = " Cavalcante"

nome_completo = nome + sobrenome

print(nome_completo)
# Out:
# Dayana Cavalcante

# %%
# exemplo de condição e decisão

idade = 18

if idade >= 18:
  print("maior de idade")
  print("você pode dirigir")
else:
  print("menor de idade")
  print("você não pode dirigir")
# Out:
# maior de idade
# você pode dirigir

# %%
lista_dados = ["a", "b", "c"]

for i in lista_dados:
  lista_dados_atualizada = i.upper()
  print(lista_dados_atualizada)
# Out:
# A
# B
# C

# %%
# Example of updating prices using a for loop and if/else

produtos = [

    {"nome": "Produto A", "preco": 100},

    {"nome": "Produto B", "preco": 250},

    {"nome": "Produto C", "preco": 50}

]

print("Preços originais:")

for produto in produtos:

    print(f"{produto['nome']}: R${produto['preco']:.2f}")

# Apply price updates

for produto in produtos:

    if produto["preco"] < 100:

        produto["preco"] *= 1.15  # Increase price by 15% for products under R$100

    elif produto["preco"] >= 100 and produto["preco"] < 200:

        produto["preco"] *= 1.10  # Increase price by 10% for products between R$100 and R$200

    else:

        produto["preco"] *= 1.05  # Increase price by 5% for products R$200 or more

print("\nPreços atualizados:")

for produto in produtos:

    print(f"{produto['nome']}: R${produto['preco']:.2f}")
# Out:
# Preços originais:
# Produto A: R$100.00
# Produto B: R$250.00
# Produto C: R$50.00
#
# Preços atualizados:
# Produto A: R$110.00
# Produto B: R$262.50
# Produto C: R$57.50

# %% [markdown]
# 10. Pandas

# %%
import pandas as pd
df = pd.read_csv("/TITANIC .csv")

# %%
df.head()
# Out:
#                                          PassengerId  Survived  Pclass  Name  \
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...       NaN     NaN   NaN
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...       NaN     NaN   NaN
# 2  3,1,3,"Heikkinen, Miss Laina",female,26,0,0,ST...       NaN     NaN   NaN
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...       NaN     NaN   NaN
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...       NaN     NaN   NaN
#
#    Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 0  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 1  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 2  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 3  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 4  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN

# %%
df.tail()
# Out:
#                                            PassengerId  Survived  Pclass  \
# 886  887,0,2,"Montvila, Rev. Juozas",male,27,0,0,21...       NaN     NaN
# 887  888,1,1,"Graham, Miss Margaret Edith",female,1...       NaN     NaN
# 888  889,0,3,"Johnston, Miss Catherine Helen ""Carr...       NaN     NaN
# 889  890,1,1,"Behr, Mr. Karl Howell",male,26,0,0,11...       NaN     NaN
# 890  891,0,3,"Dooley, Mr. Patrick",male,32,0,0,3703...       NaN     NaN
#
#      Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 886   NaN  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 887   NaN  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 888   NaN  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 889   NaN  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 890   NaN  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN

# %%
import pandas as pd
df = pd.read_csv ("/titanic 2 .csv")

# %%
import pandas as pd
df = pd.read_csv("/titanic 2 .csv",sep= ':')

# %%
df.tail()
# Out:
#     PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Ticket;Fare;Cabin;Embarked
# 886  887;0;2;Montvila, Rev. Juozas;male;27;0;0;2115...
# 887  888;1;1;Graham, Miss Margaret Edith;female;19;...
# 888  889;0;3;"Johnston, Miss Catherine Helen ""Carr...
# 889  890;1;1;Behr, Mr. Karl Howell;male;26;0;0;1113...
# 890  891;0;3;Dooley, Mr. Patrick;male;32;0;0;370376...

# %%
import pandas as pd
df=(pd.read_csv("/titanic 3 .txt",sep=','))

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 881          882         0       3                       Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss Gerda Ulrika
# 883          884         0       2            Banfield, Mr. Frederick James
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# 10.1 Pandas

# %%
import pandas as pd

df = pd.read_csv("/titanic 2 .csv", sep=";")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_nome_pass  = df['Name']
print(titanic_nome_pass)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic_duas_colunas = df[['Name', 'Age']]
print(titanic_duas_colunas)
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                                Heikkinen, Miss Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                        Graham, Miss Margaret Edith  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
len(df)
# Out:
# 891

# %%
len(df.columns)
# Out:
# 12

# %%
df.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    object
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
smallTitanic = df.head(10)[["Name", "Age"]]

print(smallTitanic)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN
# 6                            McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master Gosta Leonard   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
smallTitanicFiltered = df[df["Age"] > 30]

print(smallTitanicFiltered)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drescricao = df.describe()
print(drescricao)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000

# %%
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     712.833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
df.iloc[1:10, 0:2]
# Out:
#    PassengerId  Survived
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0
# 5            6         0
# 6            7         0
# 7            8         0
# 8            9         1
# 9           10         1

# %%
dados1 = {
    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
    'Preço': [50, 100, 150, None],
    'Quantidade': [100, 150, 300, None]
}

# %%
print(dados1)
# Out:
# {'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'], 'Preço': [50, 100, 150, None], 'Quantidade': [100, 150, 300, None]}

# %%
df1 = pd.DataFrame(dados1)
# Exibindo o DataFrame
print(df1)
print()
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis    NaN         NaN

# %%
# Substituir valores ausentes por quinhentos
df1.fillna(500, inplace=True)
print(df1)
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis  500.0       500.0

# %%
# agrupamento horizontal
import pandas as pd
# DataFrame 1: Produtos
produtos = {
    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
    'Preço': [50, 100, 200, 150]
}

df_produtos = pd.DataFrame(produtos)
# DataFrame 2: Vendas
vendas = {
    'Quantidade': [100, 150, 80, 120]
}
df_vendas = pd.DataFrame(vendas)
# Agrupar horizontalmente (adicionar as colunas de df_vendas ao df_produtos)
df_completo = pd.concat([df_produtos, df_vendas], axis=1)
# Exibir o DataFrame resultante
print(df_produtos)
print(df_vendas)
print(df_completo)
# Out:
#     Produto  Preço
# 0  Camiseta     50
# 1     Calça    100
# 2   Jaqueta    200
# 3     Tênis    150
#    Quantidade
# 0         100
# 1         150
# 2          80
# 3         120
#     Produto  Preço  Quantidade
# 0  Camiseta     50         100
# 1     Calça    100         150
# 2   Jaqueta    200          80
# 3     Tênis    150         120

# %%
# agrupamento horizontal
import pandas as pd
# DataFrame 1: Produtos
produtos = {
    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
    'Preço': [50, 100, 200, 150]
}
# DataFrame 3: Notas
Notas = {
    'Notas' : ["a" , "b" , "c" , "d"]

}
df_produtos = pd.DataFrame(produtos)
# DataFrame 2: Vendas
vendas = {
    'Quantidade': [100, 150, 80, 120]
}
df_vendas = pd.DataFrame(vendas)
# Criando o DataFrame df_Notas
df_Notas = pd.DataFrame(Notas)

# Agrupar horizontalmente (adicionar as colunas de df_vendas e df_Notas ao df_produtos)
df_completo = pd.concat([df_produtos, df_vendas, df_Notas], axis=1)
# Exibir o DataFrame resultante
print(df_produtos)
print(df_vendas)
print(df_Notas)
print(df_completo)
# Out:
#     Produto  Preço
# 0  Camiseta     50
# 1     Calça    100
# 2   Jaqueta    200
# 3     Tênis    150
#    Quantidade
# 0         100
# 1         150
# 2          80
# 3         120
#   Notas
# 0     a
# 1     b
# 2     c
# 3     d
#     Produto  Preço  Quantidade Notas
# 0  Camiseta     50         100     a
# 1     Calça    100         150     b
# 2   Jaqueta    200          80     c
# 3     Tênis    150         120     d

# %%
# agrupamento horizontal

import pandas as pd

# DataFrame 1: Produtos

produtos = {

    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],

    'Preço': [50, 100, 200, 150]

}

df_produtos = pd.DataFrame(produtos)

# DataFrame 2: Vendas

vendas = {

    'Quantidade': [100, 150, 80, 120]

}

grade = {

    'Notas': ["A", "B", "C", "D"]

}

df_vendas = pd.DataFrame(vendas)

df_grade = pd.DataFrame(grade)

df_vendas = pd.DataFrame(vendas)

# Agrupar horizontalmente (adicionar as colunas de df_vendas ao df_produtos)

df_completo = pd.concat([df_produtos, df_vendas, df_grade], axis=1)

# Calcular o Preço Total

df_completo['Preço Total'] = df_completo['Preço'] * df_completo['Quantidade']

# Exibir o DataFrame resultante

print(df_completo)
# Out:
#     Produto  Preço  Quantidade Notas  Preço Total
# 0  Camiseta     50         100     A         5000
# 1     Calça    100         150     B        15000
# 2   Jaqueta    200          80     C        16000
# 3     Tênis    150         120     D        18000

# %% [markdown]
# # 10. Visualização

# %%
notas = [8, 7, 6, 9, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]

# %%
import matplotlib.pyplot as plt

plt.hist(notas, bins=10, edgecolor="green")
plt.title("Histograma de Notas")
plt.xlabel("Notas")
plt.ylabel("Quantidade")

# Salva a imagem (antes do show)

plt.savefig("histograma_notas.png", dpi=300, bbox_inches="tight")

# %%
import pandas as pd

df = pd.DataFrame({"Notas": notas})
contagem = df["Notas"].value_counts().sort_index()
contagem.plot(kind="bar", color="skyblue", edgecolor="pink")
plt.title("Frequência das Notas")
plt.xlabel("Nota")
plt.ylabel("Quantidade")

# Salva a imagem (antes do show)

#plt.savefig("../img/barras_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
contagem.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))
plt.title("Proporção de cada Nota")
plt.ylabel("")  # remove label lateral
#plt.savefig("../img/pizza_notas.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Resumo
#  - Breve resumo do objetivo do trabalho: analisar balancetes
#  - demonstrativos contábeis para identificar padrões, indicadores e insights para tomada de decisão em empresas Lucro Real.
#
# # Objetivos
#  - Descrever o conjunto de dados contábeis.
#  - Calcular indicadores (médias, medianas, variações, tributos).
#  - Gerar gráficos que suportem conclusões.
#  - Sugerir ações a partir dos insights.

# %%
# Imports básicos
import pandas as pd

# %%
# Importei meu arquivo
df = pd.read_csv("/content/trabalho_pos_ipog .csv", sep=';', encoding='latin-1', on_bad_lines='skip')
